# %% [markdown]
# ### here in this we setup the mongodb database iint he browser
# - steps
#
# 1. import data into notebook
# 2. convert into dict(df.to_dict(orient = 'records'))
# 3. database_name, collection_name, connection_url,
# 4. records = collection.find()
# 5. data_dict = pd.DataFrame(list(colleciton.find()))

# %%
'mongodb+srv://saisriraj5:Srir@j1996@cluster0.leajo.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'

# %%
import pandas as pd

df1 = pd.read_csv("auto_imports1.csv")
df1
# Out:
#     fuel_type         body  wheel_base  length  width  heights  curb_weight  \
# 0         gas  convertible        88.6   168.8   64.1     48.8         2548
# 1         gas  convertible        88.6   168.8   64.1     48.8         2548
# 2         gas    hatchback        94.5   171.2   65.5     52.4         2823
# 3         gas        sedan        99.8   176.6   66.2     54.3         2337
# 4         gas        sedan        99.4   176.6   66.4     54.3         2824
# ..        ...          ...         ...     ...    ...      ...          ...
# 196       gas        sedan       109.1   188.8   68.9     55.5         2952
# 197       gas        sedan       109.1   188.8   68.8     55.5         3049
# 198       gas        sedan       109.1   188.8   68.9     55.5         3012
# 199    diesel        sedan       109.1   188.8   68.9     55.5         3217
# 200       gas        sedan       109.1   188.8   68.9     55.5         3062
#
# ...

# %%
data_dict = df1.to_dict(orient="records")
data_dict
# Out:
# [{'fuel_type': 'gas',
#   'body': 'convertible',
#   'wheel_base': 88.6,
#   'length': 168.8,
#   'width': 64.1,
#   'heights': 48.8,
#   'curb_weight': 2548,
#   'engine_type': 'dohc',
#   'cylinders': 'four',
#   'engine_size': 130,
#   'bore': '3.47',
#   'stroke': '2.68',
#   'comprassion': 9.0,
#   'horse_power': '111',
#   'peak_rpm': '5000',
#   'city_mpg': 21,
#   'highway_mpg': 27,
#   'price': 13495},
#  {'fuel_type': 'gas',
#   'body': 'convertible',
#   'wheel_base': 88.6,
#   'length': 168.8,
#   'width': 64.1,
#   'heights': 48.8,
#   'curb_weight': 2548,
#   'engine_type': 'dohc',
#   'cylinders': 'four',
#   'engine_size': 130,
#   'bore': '3.47',
#   'stroke': '2.68',
#   'comprassion': 9.0,
#   'horse_power': '111',
#   'peak_rpm': '5000',
#   'city_mpg': 21,
#   'highway_mpg': 27,
#   'price': 16500},
#  {'fuel_type': 'gas',
#   'body': 'hatchback',
#   'wheel_base': 94.5,
#   'length': 171.2,
#   'width': 65.5,
#   'heights': 52.4,
#   'curb_weight': 2823,
# ...

# %%
len(data)
# Out:
# 201

# %%
DB_NAME = "automobile"

COLLECTION_NAME  = "auto_data"

CONNECTION_URL = ""

# %%
from pymongo.mongo_client import MongoClient
import urllib.parse
# Encode the username and password
username = urllib.parse.quote_plus('saisriraj5')
password = urllib.parse.quote_plus('Srir@j1996')



DB_NAME = 'automobile'
COLLECTION_NAME= 'auto_data'
# Construct the encoded URI

url = 'mongodb+srv://saisriraj5:Srir@j1996@cluster0.leajo.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'




CONNECTION_URL = f'mongodb+srv://{username}:{password}@cluster0.leajo.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'


# Create a new client and connect to the server
client = MongoClient(CONNECTION_URL)

data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

#store data
rec = collection.insert_many(data_dict)

# %%
records = collection.find()
records

# %%
for i,j in enumerate(records):
    print(f"{i}: {j}")
# Out:
# 0: {'_id': ObjectId('673eddf9b9b59b78b1c833e4'), 'fuel_type': 'gas', 'body': 'convertible', 'wheel_base': 88.6, 'length': 168.8, 'width': 64.1, 'heights': 48.8, 'curb_weight': 2548, 'engine_type': 'dohc', 'cylinders': 'four', 'engine_size': 130, 'bore': '3.47', 'stroke': '2.68', 'comprassion': 9.0, 'horse_power': '111', 'peak_rpm': '5000', 'city_mpg': 21, 'highway_mpg': 27, 'price': 13495}
# 1: {'_id': ObjectId('673eddf9b9b59b78b1c833e5'), 'fuel_type': 'gas', 'body': 'convertible', 'wheel_base': 88.6, 'length': 168.8, 'width': 64.1, 'heights': 48.8, 'curb_weight': 2548, 'engine_type': 'dohc', 'cylinders': 'four', 'engine_size': 130, 'bore': '3.47', 'stroke': '2.68', 'comprassion': 9.0, 'horse_power': '111', 'peak_rpm': '5000', 'city_mpg': 21, 'highway_mpg': 27, 'price': 16500}
# ...

# %% [markdown]
# ## to convert the above collectoin into data frame

# %%
df2 = pd.DataFrame(list(collection.find()))
df2
# Out:
#                           _id fuel_type         body  wheel_base  length  \
# 0    673eddf9b9b59b78b1c833e4       gas  convertible        88.6   168.8
# 1    673eddf9b9b59b78b1c833e5       gas  convertible        88.6   168.8
# 2    673eddf9b9b59b78b1c833e6       gas    hatchback        94.5   171.2
# 3    673eddf9b9b59b78b1c833e7       gas        sedan        99.8   176.6
# 4    673eddf9b9b59b78b1c833e8       gas        sedan        99.4   176.6
# ..                        ...       ...          ...         ...     ...
# 196  673eddf9b9b59b78b1c834a8       gas        sedan       109.1   188.8
# 197  673eddf9b9b59b78b1c834a9       gas        sedan       109.1   188.8
# 198  673eddf9b9b59b78b1c834aa       gas        sedan       109.1   188.8
# 199  673eddf9b9b59b78b1c834ab    diesel        sedan       109.1   188.8
# 200  673eddf9b9b59b78b1c834ac       gas        sedan       109.1   188.8
#
#      width  heights  curb_weight engine_type cylinders  engine_size  bore  \
# ...

# %% [markdown]
# ### remove id from above data frame

# %%
if "_id" in df2.columns.to_list():
    data_df = df2.drop(columns = ['_id'])

# %%
data_df
# Out:
#     fuel_type         body  wheel_base  length  width  heights  curb_weight  \
# 0         gas  convertible        88.6   168.8   64.1     48.8         2548
# 1         gas  convertible        88.6   168.8   64.1     48.8         2548
# 2         gas    hatchback        94.5   171.2   65.5     52.4         2823
# 3         gas        sedan        99.8   176.6   66.2     54.3         2337
# 4         gas        sedan        99.4   176.6   66.4     54.3         2824
# ..        ...          ...         ...     ...    ...      ...          ...
# 196       gas        sedan       109.1   188.8   68.9     55.5         2952
# 197       gas        sedan       109.1   188.8   68.8     55.5         3049
# 198       gas        sedan       109.1   188.8   68.9     55.5         3012
# 199    diesel        sedan       109.1   188.8   68.9     55.5         3217
# 200       gas        sedan       109.1   188.8   68.9     55.5         3062
#
# ...
